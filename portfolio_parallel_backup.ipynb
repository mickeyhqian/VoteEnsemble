# %%
import numpy as np
import matplotlib.pyplot as plt
from gurobipy import Model, GRB, quicksum
# from scipy import stats

from ParallelSolve import gurobi_portfolio, majority_vote

# %%
# given budget，price vector (v_i)，mean return vector (mu_i).

# objective (minimize conditional value at risk, cvar): \min c  + 1/0.05 E[ (-sum \xi_i * v_i  * x_i - c)_+ ]

# s.t. 
# \sum x_i * v_i <= budget
# \sum \mu_i * v_i * x_i >= budget * 1.5
# x_i >= 0 integer

# %%
def sample_func(distribution_name, **dist_params):
     if hasattr(np.random, distribution_name):
        dist_func = getattr(np.random, distribution_name)
        samples = dist_func(**dist_params)
        return samples + 1 if distribution_name == "pareto" else samples
     else:
        raise ValueError(f"Unsupported distribution: {distribution_name}")
     

def sample_func_copy(distribution_name, **dist_params):
     if hasattr(np.random, distribution_name):
        dist_func = getattr(np.random, distribution_name)
        samples = dist_func(**dist_params)
        return samples + 1 if distribution_name == "pareto" else samples
     else:
        raise ValueError(f"Unsupported distribution: {distribution_name}")

def generate_covariance_matrix(m):
    A = np.random.rand(m, m)  
    cov_matrix = np.dot(A, A.T) 
    return cov_matrix

# %%
def gurobi_second_stage(sample_xi, p, x):
    k, m = sample_xi.shape
    model = Model("second_stage")
    model.setParam(GRB.Param.OutputFlag, 0)
    c = model.addVar(vtype=GRB.CONTINUOUS, name="c")
    z = model.addVars(k, lb=0, vtype=GRB.CONTINUOUS, name="z")
    
    model.setObjective(c + 1/0.05 * 1/k * quicksum(z[i] for i in range(k)), GRB.MINIMIZE)
    
    model.addConstrs(z[i] >= -sum(sample_xi[i, j] * x[j] * p[j] for j in range(m)) - c for i in range(k))
    
    model.optimize()

    if model.status == GRB.OPTIMAL:
        return model.ObjVal
    else:
        print("No optimal solution found.")
        return None

# %%
# SAA and majority vote comparison
def comparison(mu, dist_paras,p, b,B,number_of_iterations,ratio,sample_number):
    name, paras = dist_paras["name"], dist_paras["paras"]
    
    SAA_list = []
    majority_list = []
    for n in sample_number:
        SAA_intermediate = []
        majority_intermediate = []
        for _ in range(number_of_iterations):
            if name == "multivariate_normal":
                sample_n = sample_func(name, size=n, mean=mu, cov=paras)
            elif name == "pareto":
                arrays_list = []
                for i in range(len(mu)):
                    arrays_list.append(sample_func(name, size=n, a=paras[i]))
                sample_n = np.vstack(arrays_list).T
            else: 
                raise ValueError(f"Unsupported distribution: {name}")
            SAA = majority_vote(sample_n, 1, n, gurobi_portfolio, p, mu, b)
            SAA_intermediate.append(SAA)
            majority = majority_vote(sample_n, B, int(n*ratio), gurobi_portfolio, p, mu, b)
            majority_intermediate.append(majority)
            
        SAA_list.append(SAA_intermediate)
        majority_list.append(majority_intermediate)
    return SAA_list, majority_list

def evaluation(SAA_list, majority_list, mu, dist_paras, p, number_of_iterations, sample_number, large_number_sample):
    name, paras = dist_paras["name"], dist_paras["paras"]
    if name == "multivariate_normal":
        large_sample = sample_func(name, size=large_number_sample, mean=mu, cov=paras)
    elif name == "pareto":
        arrays_list = []
        for i in range(len(mu)):
            arrays_list.append(sample_func(name, size=large_number_sample, a=paras[i]))
        large_sample = np.vstack(arrays_list).T
    else:
        raise ValueError(f"Unsupported distribution: {name}")

    SAA_obj_list = []
    majority_obj_list = []
    for i in range(len(sample_number)):
        SAA_obj = 0
        majority_obj = 0
        for j in range(number_of_iterations):
            SAA_obj += gurobi_second_stage(large_sample, p, SAA_list[i][j])
            majority_obj += gurobi_second_stage(large_sample, p, majority_list[i][j])  
            
        SAA_obj = SAA_obj/number_of_iterations
        majority_obj = majority_obj/number_of_iterations

        SAA_obj_list.append(SAA_obj)
        majority_obj_list.append(majority_obj)
    return SAA_obj_list, majority_obj_list

def figure_plot(SAA_obj_list, majority_obj_list,sample_number):
    # plot the objective values of SAA and Bagging-SAA
    _, ax = plt.subplots()
    ax.plot(sample_number, SAA_obj_list, marker = 'o', markeredgecolor = 'none', color = 'blue',linestyle = 'solid', linewidth = 2, label = 'SAA')
    ax.plot(sample_number, majority_obj_list, marker = 's', markeredgecolor = 'none', color = 'red',linestyle = 'solid', linewidth = 2, label = 'Majority Vote')
    ax.set_xlabel('Number of samples', size = 20)
    ax.set_ylabel('Objective', size = 20)
    ax.legend(loc = 'lower right')
    plt.show()
    return

# %%
# Random experiments
m = 8
mu = np.random.uniform(2, 5, m)
a_ls = np.divide(mu, mu-1)
cov_matrix = generate_covariance_matrix(m)
dist_paras_pareto = {"name": "pareto", "paras": a_ls}
dist_paras_normal = {"name": "multivariate_normal", "paras": cov_matrix}

p = np.random.uniform(0, 1, m)
b = np.random.uniform(1, 3)

B = 400
number_of_iterations = 10 # Number of iterations for each sample size (use to take average)
ratio = 0.2
sample_number = np.array([2**i for i in range(5, 16)])
large_number_sample = 1000000

# %%
number_of_iterations = 20
sample_number = np.array([500*i for i in range(1, 21)])
# SAA_list, majority_list = comparison(mu, dist_paras_pareto, p, b, B, number_of_iterations, ratio, sample_number)
# SAA_obj_list, majority_obj_list = evaluation(SAA_list, majority_list, mu, dist_paras_pareto, p, number_of_iterations, sample_number, large_number_sample)
SAA_list, majority_list = comparison(mu, dist_paras_normal, p, b, B, number_of_iterations, ratio, sample_number)
SAA_obj_list, majority_obj_list = evaluation(SAA_list, majority_list, mu, dist_paras_normal, p, number_of_iterations, sample_number, large_number_sample)
figure_plot(SAA_obj_list, majority_obj_list, sample_number)
# Out:
# Set parameter Username
# Process Process-1:
# Traceback (most recent call last):
#   File "/Users/mickey/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/mickey/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/mickey/Documents/ResearchProject/BaggedSAA/code/ParallelSolve.py", line 71, in sequentialSolve
#     x_k = tuple(eval_func(sample, *eval_args))
#   File "/Users/mickey/Documents/ResearchProject/BaggedSAA/code/ParallelSolve.py", line 46, in gurobi_portfolio
#     model = Model("portfolio")
#   File "src/gurobipy/model.pxi", line 68, in gurobipy.Model.__init__
#   File "src/gurobipy/gurobi.pxi", line 32, in gurobipy.gurobi._getdefaultenv
#   File "src/gurobipy/env.pxi", line 62, in gurobipy.Env.__init__
# gurobipy.GurobiError: License expired 2023-07-13
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       2 sample_number = np.array([500*i for i in range(1, 21)])
#       3 # SAA_list, majority_list = comparison(mu, dist_paras_pareto, p, b, B, number_of_iterations, ratio, sample_number)
#       4 # SAA_obj_list, majority_obj_list = evaluation(SAA_list, majority_list, mu, dist_paras_pareto, p, number_of_iterations, sample_number, large_number_sample)
# ----> 5 SAA_list, majority_list = comparison(mu, dist_paras_normal, p, b, B, number_of_iterations, ratio, sample_number)
#       6 SAA_obj_list, majority_obj_list = evaluation(SAA_list, majority_list, mu, dist_paras_normal, p, number_of_iterations, sample_number, large_number_sample)
#       7 figure_plot(SAA_obj_list, majority_obj_list, sample_number)
#
# Cell In[6], line 20, in comparison(mu, dist_paras, p, b, B, number_of_iterations, ratio, sample_number)
#      18 else:
#      19     raise ValueError(f"Unsupported distribution: {name}")
# ---> 20 SAA = majority_vote(sample_n, 1, n, gurobi_portfolio, p, mu, b)
#      21 SAA_intermediate.append(SAA)
#      22 majority = majority_vote(sample_n, B, int(n*ratio), gurobi_portfolio, p, mu, b)
#
# File ~/Documents/ResearchProject/BaggedSAA/code/ParallelSolve.py:105, in majority_vote(sample_n, B, k, eval_func, *eval_args)
#     102     x_k = queue.get()
#     103     x_count[x_k] = x_count.get(x_k, 0) + 1
# --> 105 x_max = max(x_count, key=x_count.get)
#     106 return x_max
#
# ValueError: max() arg is an empty sequence

# %%
number_of_iterations = 50
sample_number = np.array([500*i for i in range(4, 30)])
# SAA_list, majority_list = comparison(mu, dist_paras_pareto, p, b, B, number_of_iterations, ratio, sample_number)
# SAA_obj_list, majority_obj_list = evaluation(SAA_list, majority_list, mu, dist_paras_pareto, p, number_of_iterations, sample_number, large_number_sample)
SAA_list, majority_list = comparison(mu, dist_paras_normal, p, b, B, number_of_iterations, ratio, sample_number)
SAA_obj_list, majority_obj_list = evaluation(SAA_list, majority_list, mu, dist_paras_normal, p, number_of_iterations, sample_number, large_number_sample)
figure_plot(SAA_obj_list, majority_obj_list, sample_number)

# %%
number_of_iterations = 50
sample_number = np.array([1000*i for i in range(3, 20)])
# SAA_list, majority_list = comparison(mu, dist_paras_pareto, p, b, B, number_of_iterations, ratio, sample_number)
# SAA_obj_list, majority_obj_list = evaluation(SAA_list, majority_list, mu, dist_paras_pareto, p, number_of_iterations, sample_number, large_number_sample)
SAA_list, majority_list = comparison(mu, dist_paras_normal, p, b, B, number_of_iterations, ratio, sample_number)
SAA_obj_list, majority_obj_list = evaluation(SAA_list, majority_list, mu, dist_paras_normal, p, number_of_iterations, sample_number, large_number_sample)
figure_plot(SAA_obj_list, majority_obj_list, sample_number)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[113], line 5
#       2 sample_number = np.array([1000*i for i in range(3, 20)])
#       3 # SAA_list, majority_list = comparison(mu, dist_paras_pareto, p, b, B, number_of_iterations, ratio, sample_number)
#       4 # SAA_obj_list, majority_obj_list = evaluation(SAA_list, majority_list, mu, dist_paras_pareto, p, number_of_iterations, sample_number, large_number_sample)
# ----> 5 SAA_list, majority_list = comparison(mu, dist_paras_normal, p, b, B, number_of_iterations, ratio, sample_number)
#       6 SAA_obj_list, majority_obj_list = evaluation(SAA_list, majority_list, mu, dist_paras_normal, p, number_of_iterations, sample_number, large_number_sample)
#       7 figure_plot(SAA_obj_list, majority_obj_list, sample_number)
#
# Cell In[112], line 22, in comparison(mu, dist_paras, p, b, B, number_of_iterations, ratio, sample_number)
#      20     SAA = majority_vote(sample_n, 1, n, gurobi_portfolio, p, mu, b)
#      21     SAA_intermediate.append(SAA)
# ---> 22     majority = majority_vote(sample_n, B, int(n*ratio), gurobi_portfolio, p, mu, b)
#      23     majority_intermediate.append(majority)
#      25 SAA_list.append(SAA_intermediate)
#
# Cell In[109], line 6, in majority_vote(sample_n, B, k, eval_func, *eval_args)
#       3 for _ in range(B):
#       4     # choose k samples from total n samples
#       5     sample_k = sample_n[np.random.choice(sample_n.shape[0], k, replace=False)]
# ----> 6     x_k = tuple(eval_func(sample_k, *eval_args))
#       7     x_count[x_k] = x_count.get(x_k, 0) + 1
#       9 x_max = max(x_count, key=x_count.get)
#
# Cell In[110], line 19, in gurobi_portfolio(sample_xi, p, mu, b)
#      15 z = model.addVars(k, lb=0, vtype=GRB.CONTINUOUS, name="z")
#      17 model.setObjective(c + 1/0.05 * 1/k * quicksum(z[i] for i in range(k)), GRB.MINIMIZE)
# ---> 19 model.addConstrs(z[i] >= -sum(sample_xi[i, j] * x[j] * p[j] for j in range(m)) - c for i in range(k))
#      20 model.addConstr(quicksum(mu[j] * x[j] * p[j] for j in range(m)) >= 1.5*b)
#      21 model.addConstr(quicksum(x[j] * p[j] for j in range(m)) <= b)
#
# File src/gurobipy/model.pxi:3877, in gurobipy.Model.addConstrs()
#
# Cell In[110], line 19, in <genexpr>(.0)
#      15 z = model.addVars(k, lb=0, vtype=GRB.CONTINUOUS, name="z")
#      17 model.setObjective(c + 1/0.05 * 1/k * quicksum(z[i] for i in range(k)), GRB.MINIMIZE)
# ---> 19 model.addConstrs(z[i] >= -sum(sample_xi[i, j] * x[j] * p[j] for j in range(m)) - c for i in range(k))
#      20 model.addConstr(quicksum(mu[j] * x[j] * p[j] for j in range(m)) >= 1.5*b)
#      21 model.addConstr(quicksum(x[j] * p[j] for j in range(m)) <= b)
#
# Cell In[110], line 19, in <genexpr>(.0)
#      15 z = model.addVars(k, lb=0, vtype=GRB.CONTINUOUS, name="z")
#      17 model.setObjective(c + 1/0.05 * 1/k * quicksum(z[i] for i in range(k)), GRB.MINIMIZE)
# ---> 19 model.addConstrs(z[i] >= -sum(sample_xi[i, j] * x[j] * p[j] for j in range(m)) - c for i in range(k))
#      20 model.addConstr(quicksum(mu[j] * x[j] * p[j] for j in range(m)) >= 1.5*b)
#      21 model.addConstr(quicksum(x[j] * p[j] for j in range(m)) <= b)
#
# KeyboardInterrupt:

# %%
mu, dist_paras_normal, p, b
# Out:
# (array([4.57825599, 2.59539243, 3.63529675, 3.52406055, 3.24507009,
#         4.72188993, 4.3935796 , 3.42740159]),
#  {'name': 'multivariate_normal',
#   'paras': array([[4.023997  , 2.40310981, 2.20044386, 2.17927984, 3.04517019,
#           3.13852272, 3.0678499 , 2.57802196],
#          [2.40310981, 1.92007872, 1.40783953, 1.35288294, 1.87754314,
#           2.0765766 , 2.12928102, 1.8373703 ],
#          [2.20044386, 1.40783953, 1.90733334, 1.76914087, 1.6352554 ,
#           1.70005219, 2.06525868, 1.8454927 ],
#          [2.17927984, 1.35288294, 1.76914087, 1.88579515, 1.63004875,
#           1.62722018, 1.93102905, 1.83989155],
#          [3.04517019, 1.87754314, 1.6352554 , 1.63004875, 3.2080927 ,
#           2.61255376, 2.67144999, 1.98725729],
#          [3.13852272, 2.0765766 , 1.70005219, 1.62722018, 2.61255376,
#           2.95382297, 2.66526416, 1.99690051],
#          [3.0678499 , 2.12928102, 2.06525868, 1.93102905, 2.67144999,
#           2.66526416, 3.37273352, 2.01893774],
#          [2.57802196, 1.8373703 , 1.8454927 , 1.83989155, 1.98725729,
#           1.99690051, 2.01893774, 2.27869206]])},
#  array([0.00780965, 0.44311801, 0.82218091, 0.64466618, 0.39305453,
#         0.48080274, 0.57539239, 0.49682178]),
#  1.505581876905086)

# %%
def find_parameters(m,B,number_of_iterations,ratio,sample_number,large_number_sample):
    parameter_dict = {}
    SAA_list_test = []
    majority_list_test = []
    SAA_obj_list_test = []
    majority_obj_list_test = []
    prop_best = 0

    for _ in range(10):
        mu = np.random.uniform(2.9, 3.5, m)
        a_ls = np.divide(mu, mu-1)
        dist_paras_pareto = {"name": "pareto", "paras": a_ls}
        p = np.random.uniform(0, 2, m)
        b = np.random.uniform(2, 3)

        SAA_list, majority_list = comparison(mu, dist_paras_pareto, p, b, B, number_of_iterations, ratio, sample_number)
        SAA_obj_list, majority_obj_list = evaluation(SAA_list, majority_list, mu, dist_paras_pareto, p, number_of_iterations, sample_number, large_number_sample)

        prop = sum((SAA_obj_list[i]-majority_obj_list[i])/SAA_obj_list[i] for i in range(len(sample_number)//2,len(sample_number)))
        if prop > prop_best:
            prop_best = prop
            parameter_dict["mu"] = mu
            parameter_dict["a_ls"] = a_ls
            parameter_dict["p"] = p
            parameter_dict["b"] = b
            SAA_list_test = SAA_list
            majority_list_test = majority_list
            SAA_obj_list_test = SAA_obj_list
            majority_obj_list_test = majority_obj_list
    
    return parameter_dict, SAA_list_test, majority_list_test, SAA_obj_list_test, majority_obj_list_test

# %%
# A good configuration under normal distribution
# m = 5
# mu = np.array([2.26833837, 2.99724413, 2.05634484, 2.22041616, 2.27772837])

# cov_matrix = np.array([[1.53992965, 1.45799569, 1.33721954, 1.29951018, 1.27703683],
#  [1.45799569, 1.46349095, 1.28561251, 1.11928718, 1.2290614 ],
#  [1.33721954, 1.28561251, 2.59160798, 1.50136609, 1.95532864],
#  [1.29951018, 1.11928718, 1.50136609, 1.58527353, 1.23659311],
#  [1.27703683, 1.2290614,  1.95532864, 1.23659311, 1.59685207]])

# p = np.array([0.21428391, 0.09577878, 0.82863508, 0.27561237, 0.88738926])
# b = 2.3308601852993753

# %%
# Testing: SAA and majority vote comparison - parameters setup

sample_number = np.array([2**i for i in range(10, 17)])
number_of_iterations = 10 # Number of iterations for each sample size (use to take average)
m = 3 # Number of items


# Generate samples for evaluation of optimal SAA and majority vote
large_number_sample = 1000000 
a_ls = np.full(m, 2) #np.random.rand(m)+1 # Pareto distribution parameter
arrays_list = []
for i in range(m):
    arrays_list.append(sample_func('pareto', size=large_number_sample, a=a_ls[i]))
large_sample = np.vstack(arrays_list).T

parameter_list = []
SAA_list_test = []
majority_list_test = []
SAA_obj_list_test = []
majority_obj_list_test = []

for num_test in range(10):
    print(num_test)
    c = float(np.random.uniform(3, 4, size=1)[0]) # Cost 
    q = float(np.random.uniform(0, 2, size=1)[0]) # Budget
    r = np.random.uniform(3, 4, size=m) # Rewards
    
    SAA_obj = 0
    majority_obj = 0
    flag = 0
    for n in sample_number:
        SAA_intermediate = []
        majority_intermediate = []
        for j in range(number_of_iterations):
            arrays_list = []
            for i in range(m):
                arrays_list.append(sample_func('pareto', size=n, a=a_ls[i]))
            sample_n = np.vstack(arrays_list).T
            SAA = majority_vote(sample_n, 1, n, gurobi_SSKP, r,c,q)
            SAA_intermediate.append(SAA)
            SAA_obj += optimal_eval(large_sample, SAA, r, c, q)

            majority = majority_vote(sample_n, 300, int(n/10), gurobi_SSKP, r,c,q)
            majority_intermediate.append(majority)
            majority_obj += optimal_eval(large_sample, majority, r, c, q)

        SAA_obj = SAA_obj/number_of_iterations
        majority_obj = majority_obj/number_of_iterations

        if SAA_obj > majority_obj:
            flag = 1
            break

    if flag == 1:
        continue 
    
    parameter_list.append([m, c, q, r])
    SAA_obj_list_test.append(SAA_obj)
    majority_obj_list_test.append(majority_obj)
# Out:
# 0
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-02-20
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 1024 rows, 1027 columns and 4096 nonzeros
# Model fingerprint: 0xe3b60d0c
# Variable types: 1024 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+02]
#   Objective range  [3e-03, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.6809689
# Presolve removed 1024 rows and 1027 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.68097 4.68097 4.68097 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.680969040191e+00, best bound 4.680969040191e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x46bf5085
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.4952209
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.49522 5.49522 5.49522 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.495221003034e+00, best bound 5.495221003034e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x3cc14050
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.5312955
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.5313 5.5313 5.5313 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.531295609791e+00, best bound 5.531295609791e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x551b1a21
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [7e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.0377764
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.03778 5.03778 5.03778 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.037776505033e+00, best bound 5.037776505033e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xeb307ff3
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.5048366
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.50484 5.50484 5.50484 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.504836660088e+00, best bound 5.504836660088e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x64b2c207
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.3766979
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.3767 5.3767 5.3767 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.376698016377e+00, best bound 5.376698016377e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xc98ced48
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.6532809
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.65328 4.65328 4.65328 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.653281006068e+00, best bound 4.653281006068e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x22ca6378
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [7e-04, 9e+00]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.8404809
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.84048 5.84048 5.84048 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.840480976413e+00, best bound 5.840480976413e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x73761777
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [7e-04, 9e+00]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.9059633
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.90596 5.90596 5.90596 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.905963389006e+00, best bound 5.905963389006e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x1ab4a53e
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.5877471
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.58775 4.58775 4.58775 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.587747164403e+00, best bound 4.587747164403e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xd7379d2c
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.6386963
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.6387 4.6387 4.6387 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.638696377951e+00, best bound 4.638696377951e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xdea77028
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 4e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.1231556
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.12316 4.12316 4.12316 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.123155709615e+00, best bound 4.123155709615e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x30c4ed83
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.1294888
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 6.12949 6.12949 6.12949 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.129488870494e+00, best bound 6.129488870494e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x4d4328a9
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 9e+00]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.0137357
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 6.01374 6.01374 6.01374 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.013735743553e+00, best bound 6.013735743553e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x43c01d02
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [7e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.1531670
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.15317 5.15317 5.15317 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.153167176418e+00, best bound 5.153167176418e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x8cb9d12a
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 1e+02]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 1.7222300
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.46376 4.46376 1.72223 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.463759585214e+00, best bound 4.463759585214e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xb7efbd1d
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 4e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.0071879
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.00719 4.00719 4.00719 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.007188033462e+00, best bound 4.007188033462e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xed5fd2a2
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.7382158
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.73822 4.73822 4.73822 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.738215864441e+00, best bound 4.738215864441e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x639faffb
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 8e+00]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.7726218
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.77262 5.77262 5.77262 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.772621972978e+00, best bound 5.772621972978e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xa9410c09
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.2927293
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.29273 4.29273 4.29273 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.292729415763e+00, best bound 4.292729415763e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x154824d1
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [7e-04, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.4813542
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.48135 5.48135 5.48135 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.481354312862e+00, best bound 5.481354312862e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xdb4675c6
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 1e+02]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 1.8519058
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.64536 4.64536 1.85191 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.645359879051e+00, best bound 4.645359879051e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x22a4f774
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [7e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.9583565
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.95836 4.95836 4.95836 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.958356585679e+00, best bound 4.958356585679e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xab942843
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 1e+02]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 0.9510411
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 3.40548 3.40548 0.951041 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.405476106823e+00, best bound 3.405476106823e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x47364c56
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.5880460
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.4424 4.4424 3.58805 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.442397214270e+00, best bound 4.442397214270e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x26c5bd46
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 4e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.4479539
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.55185 4.55185 4.44795 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.551851135307e+00, best bound 4.551851135307e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xb0786954
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.7824312
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.78243 5.78243 5.78243 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.782431293635e+00, best bound 5.782431293635e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x2a8b4350
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [7e-04, 4e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.0040862
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.20337 4.20337 4.00409 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.203365624264e+00, best bound 4.203365624264e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x20f5666a
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.2498686
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.24987 5.24987 5.24987 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.249868729620e+00, best bound 5.249868729620e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xe0769774
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.9562558
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.88785 4.88785 3.95626 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.887851264060e+00, best bound 4.887851264060e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x933a8eeb
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.4359495
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.43595 5.43595 5.43595 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.435949585892e+00, best bound 5.435949585892e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xa2034a1f
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.2839418
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.28394 5.28394 5.28394 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.283941954938e+00, best bound 5.283941954938e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x536cd6a5
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.2104593
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.21046 5.21046 5.21046 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.210459357074e+00, best bound 5.210459357074e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x1695ed36
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.8492056
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 3.98375 3.98375 3.84921 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.983747078527e+00, best bound 3.983747078527e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x8c88a440
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 8e+00]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.8793803
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.87938 5.87938 5.87938 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.879380421630e+00, best bound 5.879380421630e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x5fc2ba70
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 4e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.0267169
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.07278 4.07278 4.02672 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.072779851223e+00, best bound 4.072779851223e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xf973061b
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 8e+00]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.9162872
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.91629 5.91629 5.91629 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.916287292445e+00, best bound 5.916287292445e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x39da7ac7
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 7e+00]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.7601130
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 6.76011 6.76011 6.76011 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.760113104487e+00, best bound 6.760113104487e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x9c9428cc
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.2369320
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.23693 4.23693 4.23693 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.236932129103e+00, best bound 4.236932129103e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x4feb37d2
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.7210840
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.72108 4.72108 4.72108 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.721084060174e+00, best bound 4.721084060174e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xdb65ffdf
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.8025685
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.80257 4.80257 4.80257 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.802568581900e+00, best bound 4.802568581900e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x102a6cc2
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 4e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 1.7601749
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 3.10944 3.10944 1.76017 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.109441780079e+00, best bound 3.109441780079e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x902512cc
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 8e+00]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.1749808
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 6.17498 6.17498 6.17498 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.174980912158e+00, best bound 6.174980912158e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x9e12138f
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.1899835
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 6.18998 6.18998 6.18998 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.189983594382e+00, best bound 6.189983594382e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x6f4ebb4e
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [7e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.6644730
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.66447 5.66447 5.66447 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.664473077404e+00, best bound 5.664473077404e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x3eaf8193
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.6069737
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.60697 5.60697 5.60697 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.606973744535e+00, best bound 5.606973744535e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xa8171d32
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.8608185
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.86082 5.86082 5.86082 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.860818621093e+00, best bound 5.860818621093e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xb57a6c8d
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.2623646
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.41341 4.41341 4.26236 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.413406263229e+00, best bound 4.413406263229e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x1ea28fc6
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 4e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.6951625
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# ...
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.8667971
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.8668 4.8668 4.8668 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.866797240346e+00, best bound 4.866797240346e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x84e5bf2f
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.2544596
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.25446 4.25446 4.25446 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.254459636034e+00, best bound 4.254459636034e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xde067b26
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.8843116
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.88431 4.88431 4.88431 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.884311713418e+00, best bound 4.884311713418e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x5df46444
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 5e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.6533370
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 3.65334 3.65334 3.65334 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.653337059735e+00, best bound 3.653337059735e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x78050686
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 2.3979845
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 2.88501 2.88501 2.39798 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.885010446180e+00, best bound 2.885010446180e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x56bf8281
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.7344743
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.73447 4.73447 4.73447 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.734474428076e+00, best bound 4.734474428076e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x61303987
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.0536065
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.05361 4.05361 4.05361 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.053606576670e+00, best bound 4.053606576670e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x9dab5d3f
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 6e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.0109520
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.01095 4.01095 4.01095 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.010952085721e+00, best bound 4.010952085721e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x5c269b86
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 6e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 2.9591372
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 3.44833 3.44833 2.95914 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.448333198299e+00, best bound 3.448333198299e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x315c0f73
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 2.9522461
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 3.1049 3.1049 2.95225 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.104903773342e+00, best bound 3.104903773342e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xca940d97
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.8718624
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.87186 4.87186 4.87186 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.871862492624e+00, best bound 4.871862492624e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xa0958895
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.1469207
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.14692 5.14692 5.14692 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.146920854638e+00, best bound 5.146920854638e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x4dea361b
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.7305850
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 4.73059 4.73059 4.73058 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.730585058228e+00, best bound 4.730585058228e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xd52d2f26
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 6e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.1354028
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 5.1354 5.1354 5.1354 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.135402908222e+00, best bound 5.135402908222e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xd903bc34
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.5213035
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 4: 3.5213 3.5213 3.5213 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.521303580655e+00, best bound 3.521303580655e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1 Pro
#
# Interrupt request receivedThread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x0bdead39
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 0
#
# Solve interrupted
# Best objective -, best bound -, gap -
# No optimal solution found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 43
#      40 SAA_intermediate.append(SAA)
#      41 SAA_obj += optimal_eval(larger_sample, SAA, r, c, q)
# ---> 43 majority = majority_vote(sample_n, 300, int(n/10), gurobi_SSKP, r,c,q)
#      44 majority_intermediate.append(majority)
#      45 majority_obj += optimal_eval(larger_sample, majority, r, c, q)
#
# Cell In[6], line 6, in majority_vote(sample_n, B, k, eval_func, *eval_args)
#       3 for _ in range(B):
#       4     # choose k samples from total n samples
#       5     sample_k = sample_n[np.random.choice(sample_n.shape[0], k, replace=False)]
# ----> 6     x_k = tuple(eval_func(sample_k, *eval_args))
#       7     x_count[x_k] = x_count.get(x_k, 0) + 1
#       9 x_max = max(x_count, key=x_count.get)
#
# TypeError: 'NoneType' object is not iterable
