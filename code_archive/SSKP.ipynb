# %%
import numpy as np
import matplotlib.pyplot as plt
from gurobipy import Model, GRB
from scipy import stats
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
def gurobi_SSKP(sample_k, r, c, q):
    # input:
    # sample_k (weight matrix): 2d numpy array of shape (k, m), where m is the number of items, k is the number of samples
    # r (reward vector): 1d numpy array of shape (m, )
    # c (cost vector): scalar
    # q (budget): scalar
    # output: 
    # x (selection vector): 1d numpy array of shape (m, )
    k, m = sample_k.shape
    model = Model("SSKP")
    x = model.addVars(m, vtype=GRB.BINARY, name="x")
    z = model.addVars(k, lb=0, vtype=GRB.CONTINUOUS, name="z")

    model.setObjective(sum(r[i] * x[i] for i in range(m)) - c/k * sum(z[j] for j in range(k)), GRB.MAXIMIZE)

    for j in range(k):
        model.addConstr(z[j] >= sum(sample_k[j, i] * x[i] for i in range(m)) - q, f"budget_{j}")

    model.optimize()

    if model.status == GRB.OPTIMAL:
        x_opt = np.array([x[i].X for i in range(m)])
        z_opt = np.array([z[j].X for j in range(k)])
        return x_opt
    else:
        print("No optimal solution found.")
        return None

# %%
def sample_func(distribution_name, **dist_params):
     if hasattr(np.random, distribution_name):
        # Access the distribution function dynamically
        dist_func = getattr(np.random, distribution_name)
        # Generate samples
        samples = dist_func(**dist_params)
        return samples
     else:
        raise ValueError(f"Unsupported distribution: {distribution_name}")

# %%
def majority_vote(sample_n, B, k, eval_func, *eval_args):
    x_count = {}
    for _ in range(B):
        # choose k samples from total n samples
        sample_k = sample_n[np.random.choice(sample_n.shape[0], k, replace=False)]
        x_k = tuple(eval_func(sample_k, *eval_args))
        x_count[x_k] = x_count.get(x_k, 0) + 1
    
    x_max = max(x_count, key=x_count.get)
    return x_max

# %%
def optimal_eval(sample, x, r, c, q):
     # sample: large number * m matrix
     expected_cost = 0
     for w in sample:
          expected_cost += max(sum(w[i] * x[i] for i in range(len(x)))-q, 0)
     expected_cost = expected_cost/len(sample)
     opt = sum(r[i] * x[i] for i in range(len(x))) - c * expected_cost
     return opt

# %%
# Parameters setup

m = 3 # Number of items
c = 5 # Cost 
q = 1 # Budget
r = np.random.uniform(3, 4, size=m) # Rewards

# Generate samples for evaluation of optimal SAA and majority vote
large_number_sample = 1000000 
a_ls = np.full(m, 2) #np.random.rand(m)+1 # Pareto distribution parameter
arrays_list = []
for i in range(m):
    arrays_list.append(sample_func('pareto', size=large_number_sample, a=a_ls[i]))
    larger_sample = np.vstack(arrays_list).T

sample_number = np.array([2**i for i in range(10, 17)])
number_of_iterations = 10 # Number of iterations for each sample size (use to take average)

# %%
# SAA and majority vote comparison

SAA_list = []
majority_list = []
for n in sample_number:
    SAA_intermediate = []
    majority_intermediate = []
    for _ in range(number_of_iterations):
        arrays_list = []
        for i in range(m):
            arrays_list.append(sample_func('pareto', size=n, a=a_ls[i]))
            sample_n = np.vstack(arrays_list).T
        SAA = majority_vote(sample_n, 1, n, gurobi_SSKP, r,c,q)
        SAA_intermediate.append(SAA)

        majority = majority_vote(sample_n, 100, int(n/10), gurobi_SSKP, r,c,q)
        majority_intermediate.append(majority)
        
    SAA_list.append(SAA_intermediate)
    majority_list.append(majority_intermediate)

SAA_obj_list = []
majority_obj_list = []
for i in range(len(sample_number)):
    SAA_obj = 0
    majority_obj = 0
    for j in range(number_of_iterations):
        SAA_obj += optimal_eval(larger_sample, SAA_list[i][j], r, c, q)
        SAA_obj = SAA_obj/number_of_iterations
        majority_obj += optimal_eval(larger_sample, majority_list[i][j], r, c, q)
        majority_obj = majority_obj/number_of_iterations

    SAA_obj_list.append(SAA_obj)
    majority_obj_list.append(majority_obj)
        

fig2, ax2 = plt.subplots()
ax2.plot(sample_number, SAA_obj_list, marker = 'o', markeredgecolor = 'none', color = 'blue',linestyle = 'solid', linewidth = 2, label = 'SAA')
ax2.plot(sample_number, majority_obj_list, marker = 's', markeredgecolor = 'none', color = 'red',linestyle = 'solid', linewidth = 2, label = 'Majority Vote')
ax2.set_xlabel('Number of samples', size = 20)
ax2.set_ylabel('Objective', size = 20)
ax2.legend(loc = 'lower right')
plt.show()

# %%
start = 3
end = 7
fig2, ax2 = plt.subplots()
ax2.plot(sample_number[start:end], SAA_obj_list[start:end], marker = 'o', markeredgecolor = 'none', color = 'blue',linestyle = 'solid', linewidth = 2, label = 'SAA')
ax2.plot(sample_number[start:end], majority_obj_list[start:end], marker = 's', markeredgecolor = 'none', color = 'red',linestyle = 'solid', linewidth = 2, label = 'Majority Vote')
ax2.set_xlabel('Number of samples', size = 20)
ax2.set_ylabel('Objective', size = 20)
ax2.legend(loc = 'lower right')
plt.show()

# %%
# Testing: SAA and majority vote comparison - parameters setup

sample_number = np.array([2**i for i in range(10, 15)])
number_of_iterations = 5 # Number of iterations for each sample size (use to take average)
m = 3 # Number of items


# Generate samples for evaluation of optimal SAA and majority vote
large_number_sample = 100000
a_ls = np.full(m, 2) #np.random.rand(m)+1 # Pareto distribution parameter
arrays_list = []
for i in range(m):
    arrays_list.append(sample_func('pareto', size=large_number_sample, a=a_ls[i]))
    larger_sample = np.vstack(arrays_list).T

parameter_list = []
SAA_list_test = []
majority_list_test = []
SAA_obj_list_test = []
majority_obj_list_test = []

for num_test in range(5):
    print(num_test)
    c = float(np.random.uniform(3, 4, size=1)[0]) # Cost 
    q = float(np.random.uniform(0, 2, size=1)[0]) # Budget
    r = np.random.uniform(3, 4, size=m) # Rewards
    
    SAA_obj = 0
    majority_obj = 0
    flag = 0
    for n in sample_number:
        SAA_intermediate = []
        majority_intermediate = []
        for j in range(number_of_iterations):
            arrays_list = []
            for i in range(m):
                arrays_list.append(sample_func('pareto', size=n, a=a_ls[i]))
                sample_n = np.vstack(arrays_list).T
            SAA = majority_vote(sample_n, 1, n, gurobi_SSKP, r,c,q)
            SAA_intermediate.append(SAA)
            SAA_obj += optimal_eval(larger_sample, SAA, r, c, q)

            majority = majority_vote(sample_n, 300, int(n/10), gurobi_SSKP, r,c,q)
            majority_intermediate.append(majority)
            majority_obj += optimal_eval(larger_sample, majority, r, c, q)

        SAA_obj = SAA_obj/number_of_iterations
        majority_obj = majority_obj/number_of_iterations

        if SAA_obj > majority_obj:
            flag = 1
            break

    if flag == 1:
        continue 
    
    parameter_list.append([m, c, q, r])
    SAA_obj_list_test.append(SAA_obj)
    majority_obj_list_test.append(majority_obj)
# Out:
# 0
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-02-25
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1024 rows, 1027 columns and 4096 nonzeros
# Model fingerprint: 0xbea43645
# Variable types: 1024 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 7e+01]
#   Objective range  [3e-03, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.6195818
# Presolve removed 1024 rows and 1027 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.61958 4.61958 -0
# No other solutions better than 4.61958
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.619581838870e+00, best bound 4.619581838870e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x94cc4dc5
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.3072124
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.30721 4.30721 -0
# No other solutions better than 4.30721
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.307212408274e+00, best bound 4.307212408274e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xf8c5993a
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.4053180
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.40532 4.40532 -0
# No other solutions better than 4.40532
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.405318079886e+00, best bound 4.405318079886e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x9aa31c1f
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.6659132
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.66591 5.66591 -0
# No other solutions better than 5.66591
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.665913197323e+00, best bound 5.665913197323e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x88960be4
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 4e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 2.8218749
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 2.82187 2.82187 -0
# No other solutions better than 2.82187
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.821874959726e+00, best bound 2.821874959726e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xe1449279
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.0969973
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.097 5.097 -0
# No other solutions better than 5.097
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.096997377486e+00, best bound 5.096997377486e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x9efb30a3
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.2560976
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.2561 5.2561 -0
# No other solutions better than 5.2561
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.256097682288e+00, best bound 5.256097682288e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x942c6eab
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [6e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.7425007
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.7425 4.7425 -0
# No other solutions better than 4.7425
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.742500755286e+00, best bound 4.742500755286e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xd8502d67
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.7828559
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.78286 4.78286 -0
# No other solutions better than 4.78286
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.782855899485e+00, best bound 4.782855899485e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x649125ba
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.3867401
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.38674 5.38674 -0
# No other solutions better than 5.38674
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.386740189015e+00, best bound 5.386740189015e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xb2921565
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.1680588
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 3.55717 3.55717 3.16806 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.557169973141e+00, best bound 3.557169973141e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x20f25b20
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.0638695
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.06387 5.06387 -0
# No other solutions better than 5.06387
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.063869590371e+00, best bound 5.063869590371e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xc54e0222
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.3422834
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 3.34228 3.34228 -0
# No other solutions better than 3.34228
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.342283404838e+00, best bound 3.342283404838e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x8d426aa8
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 4e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.6203004
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 3.6203 3.6203 -0
# No other solutions better than 3.6203
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.620300473752e+00, best bound 3.620300473752e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xd6439142
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 7e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 2.5914327
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 3.01293 3.01293 2.59143 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.012927196091e+00, best bound 3.012927196091e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x4ef3458d
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.5922841
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.59228 4.59228 -0
# No other solutions better than 4.59228
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.592284112880e+00, best bound 4.592284112880e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x7f08aee7
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.5560001
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 3.556 3.556 -0
# No other solutions better than 3.556
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.556000093901e+00, best bound 3.556000093901e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x01793fdd
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.9877519
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.98775 4.98775 -0
# No other solutions better than 4.98775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.987751951461e+00, best bound 4.987751951461e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xb529134e
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.4764393
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.47644 5.47644 -0
# No other solutions better than 5.47644
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.476439336420e+00, best bound 5.476439336420e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x452eeb33
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.8768995
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 3.8769 3.8769 -0
# No other solutions better than 3.8769
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.876899571822e+00, best bound 3.876899571822e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x59e09ea2
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.6842149
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.68421 4.68421 -0
# No other solutions better than 4.68421
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.684214935596e+00, best bound 4.684214935596e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x7e378f7d
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.2041868
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.20419 5.20419 -0
# No other solutions better than 5.20419
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.204186839006e+00, best bound 5.204186839006e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x98b5d0a3
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.9316326
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6.93163 6.93163 -0
# No other solutions better than 6.93163
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.931632627997e+00, best bound 6.931632627997e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x264f63e1
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.0890368
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.08904 5.08904 -0
# No other solutions better than 5.08904
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.089036795505e+00, best bound 5.089036795505e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x700812da
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.5203986
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.5204 5.5204 -0
# No other solutions better than 5.5204
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.520398633054e+00, best bound 5.520398633054e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x66252fb8
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.3543376
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.35434 4.35434 -0
# No other solutions better than 4.35434
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.354337640088e+00, best bound 4.354337640088e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xa5e87902
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.9807902
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 3.98079 3.98079 -0
# No other solutions better than 3.98079
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.980790278793e+00, best bound 3.980790278793e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xa26fad40
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 8e+00]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.0452402
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6.04524 6.04524 -0
# No other solutions better than 6.04524
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.045240192496e+00, best bound 6.045240192496e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xa24dc645
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.8088564
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.80886 4.80886 -0
# No other solutions better than 4.80886
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.808856430341e+00, best bound 4.808856430341e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xc14070d0
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 8e+00]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.4378064
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6.43781 6.43781 -0
# No other solutions better than 6.43781
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.437806470390e+00, best bound 6.437806470390e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x160a8b57
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.1490415
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.14904 5.14904 -0
# No other solutions better than 5.14904
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.149041572092e+00, best bound 5.149041572092e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xb3b339f0
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.2058980
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.2059 5.2059 -0
# No other solutions better than 5.2059
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.205898061637e+00, best bound 5.205898061637e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x021f7aeb
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.4739931
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 4.64105 4.64105 4.47399 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.641051532573e+00, best bound 4.641051532573e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xd0023764
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.6116900
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 3.62781 3.62781 3.61169 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.627814400845e+00, best bound 3.627814400845e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x7e262604
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.1107491
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.11075 5.11075 -0
# No other solutions better than 5.11075
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.110749152339e+00, best bound 5.110749152339e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x656c0862
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.8414987
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.8415 5.8415 -0
# No other solutions better than 5.8415
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.841498785594e+00, best bound 5.841498785594e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x000914d4
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.8819311
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.88193 4.88193 -0
# No other solutions better than 4.88193
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.881931176253e+00, best bound 4.881931176253e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x9bae2547
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.9867751
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 3.98678 3.98678 -0
# No other solutions better than 3.98678
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.986775093089e+00, best bound 3.986775093089e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xb8b07f15
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.2279388
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.22794 4.22794 -0
# No other solutions better than 4.22794
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.227938842365e+00, best bound 4.227938842365e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x7c3e6f17
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.8432487
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.84325 4.84325 -0
# No other solutions better than 4.84325
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.843248785655e+00, best bound 4.843248785655e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xe9f3b9a0
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.1339018
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6.1339 6.1339 -0
# No other solutions better than 6.1339
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.133901831811e+00, best bound 6.133901831811e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x57bcf020
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.4898455
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.48985 4.48985 -0
# No other solutions better than 4.48985
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.489845605175e+00, best bound 4.489845605175e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xa3256934
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [5e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.9372520
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.93725 5.93725 -0
# No other solutions better than 5.93725
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.937252010425e+00, best bound 5.937252010425e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xa547ecdf
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 4.9276004
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 4.9276 4.9276 -0
# No other solutions better than 4.9276
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.927600455553e+00, best bound 4.927600455553e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x8006246a
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-04, 9e+00]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.6427701
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.64277 5.64277 -0
# No other solutions better than 5.64277
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.642770114721e+00, best bound 5.642770114721e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x8a275c90
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.1620671
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6.16207 6.16207 -0
# No other solutions better than 6.16207
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.162067110295e+00, best bound 6.162067110295e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xcb9f71d9
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.4694569
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.46946 5.46946 -0
# No other solutions better than 5.46946
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.469456886662e+00, best bound 5.469456886662e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x90106d37
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.5640545
# Presolve removed 102 rows and 105 columns
# ...
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6.16013 6.16013 -0
# No other solutions better than 6.16013
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.160133048906e+00, best bound 6.160133048906e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x1a92cd0a
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.6940089
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.69401 5.69401 -0
# No other solutions better than 5.69401
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.694008901216e+00, best bound 5.694008901216e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x74bb9edb
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.5197806
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.51978 5.51978 -0
# No other solutions better than 5.51978
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.519780629151e+00, best bound 5.519780629151e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x275adbc0
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [8e-04, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.7476940
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.74769 5.74769 -0
# No other solutions better than 5.74769
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.747694029615e+00, best bound 5.747694029615e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x3f5364e3
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 3e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.2696129
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.26961 5.26961 -0
# No other solutions better than 5.26961
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.269612900355e+00, best bound 5.269612900355e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x1a0c5b38
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.8601592
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.86016 5.86016 -0
# No other solutions better than 5.86016
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.860159231884e+00, best bound 5.860159231884e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xa81a9c56
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.3229184
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6.32292 6.32292 -0
# No other solutions better than 6.32292
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.322918426610e+00, best bound 6.322918426610e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x1d3a6ff5
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.2325436
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6.23254 6.23254 -0
# No other solutions better than 6.23254
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.232543597231e+00, best bound 6.232543597231e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x909a9d3f
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.3441171
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.34412 5.34412 -0
# No other solutions better than 5.34412
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.344117085685e+00, best bound 5.344117085685e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x4dbb1e62
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.0280706
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.14 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.02807 5.02807 -0
# No other solutions better than 5.02807
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.028070623704e+00, best bound 5.028070623704e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xcc4188f3
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.7581258
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6.75813 6.75813 -0
# No other solutions better than 6.75813
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.758125848560e+00, best bound 6.758125848560e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xd603e406
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 1e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.6488190
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.64882 5.64882 -0
# No other solutions better than 5.64882
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.648819072993e+00, best bound 5.648819072993e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x931af862
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 5.3131170
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 5.31312 5.31312 -0
# No other solutions better than 5.31312
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.313117001870e+00, best bound 5.313117001870e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x9e17f9a7
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 7e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 3.4542350
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 4: 5.04694 5.04694 3.45423 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.046936697980e+00, best bound 5.046936697980e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0x7e48836a
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 9e+00]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective -0.0000000
# Found heuristic solution: objective 6.7502754
# Presolve removed 102 rows and 105 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 3: 6.75028 6.75028 -0
# No other solutions better than 6.75028
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.750275407364e+00, best bound 6.750275407364e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[rosetta2] - Darwin 21.3.0 21D62)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 102 rows, 105 columns and 408 nonzeros
# Model fingerprint: 0xe955e8df
# Variable types: 102 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [2e-04, 2e+01]
#   Objective range  [3e-02, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#
# Interrupt request received
#   RHS range        [2e+00, 2e+00]
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Solve interrupted
# Best objective -, best bound -, gap -
# No optimal solution found.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [8], line 43
#      40 SAA_intermediate.append(SAA)
#      41 SAA_obj += optimal_eval(larger_sample, SAA, r, c, q)
# ---> 43 majority = majority_vote(sample_n, 300, int(n/10), gurobi_SSKP, r,c,q)
#      44 majority_intermediate.append(majority)
#      45 majority_obj += optimal_eval(larger_sample, majority, r, c, q)
#
# Cell In [5], line 6, in majority_vote(sample_n, B, k, eval_func, *eval_args)
#       3 for _ in range(B):
#       4     # choose k samples from total n samples
#       5     sample_k = sample_n[np.random.choice(sample_n.shape[0], k, replace=False)]
# ----> 6     x_k = tuple(eval_func(sample_k, *eval_args))
#       7     x_count[x_k] = x_count.get(x_k, 0) + 1
#       9 x_max = max(x_count, key=x_count.get)
#
# TypeError: 'NoneType' object is not iterable

# %%
len(parameter_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 len(parameter_list)
#
# NameError: name 'parameter_list' is not defined

# %%
print(len(SAA_obj_list_test))
print(SAA_obj_list_test)
print(majority_obj_list_test)

# %%
# normal distribution comparison between SAA and majority vote
def u(x, u, q):
    return sum(u_i * x_i for u_i, x_i in zip(u, x)) - q

def var(x,std):
    return sum(std_i**2 * x_i**2 for std_i, x_i in zip(std, x))

def phi(x):
    return stats.norm.cdf(x, loc=0, scale=1)

def g(x, r, c, q, avg, std):
    expect_obj = sum(r_i * x_i for r_i, x_i in zip(r, x)) \
        - c * (u(x,avg,q) * phi(u(x,avg,q)/np.sqrt(var(x,std))) \
               + np.sqrt(var(x,std)/(2*np.pi)) * np.exp(-u(x,avg,q)**2/(2*var(x,std))))
    return expect_obj

m = 3 # Number of items
c = 5 # Cost 
q = 10 # Budget
r = np.random.uniform(3, 4, size=m) # Rewards

# generate n samples with iid normal distribution
avg =  np.random.randint(1, 5, size=m)
std =  np.random.randint(10, 20, size=m)


SAA_list_normal = []
SAA_obj_list_normal = []
majority_list_normal = []
majority_obj_list_normal = []
sample_number = np.arange(20, 1050, 50)
for ite in sample_number:
    arrays_list = []
    n = ite
    for i in range(m):
        arrays_list.append(sample_func('normal', size=n, loc=avg[i], scale=std[i]))
        sample_n = np.vstack(arrays_list).T
    SAA = majority_vote(sample_n, 1, n, gurobi_SSKP, r,c,q)
    SAA_list_normal.append(SAA)
    SAA_obj = g(SAA, r, c, q, avg, std)
    SAA_obj_list_normal.append(SAA_obj)

    majority = majority_vote(sample_n, 40, int(n/10), gurobi_SSKP, r,c,q)
    majority_list_normal.append(majority)
    majority_obj = g(majority, r, c, q, avg, std)
    majority_obj_list_normal.append(majority_obj)

fig1, ax1 = plt.subplots()
ax1.plot(sample_number, SAA_obj_list_normal, marker = 'o', markeredgecolor = 'none', color = 'blue',linestyle = 'solid', linewidth = 2, label = 'SAA')
ax1.plot(sample_number, majority_obj_list_normal, marker = 's', markeredgecolor = 'none', color = 'red',linestyle = 'solid', linewidth = 2, label = 'Majority Vote')
ax1.set_xlabel('Number of samples', size = 20)
ax1.set_ylabel('Objective', size = 20)
ax1.legend(loc = 'lower right')
plt.show()

# %%
print(SAA_list_normal)
print(majority_list_normal)
print(SAA_obj_list_normal)
print(majority_obj_list_normal)
